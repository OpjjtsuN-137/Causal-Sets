# %%
#Selecting a random point through sprinkling to later add to our relations matrix to calculate S prime

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import math
import random

A=1
a5=[]
q=range(500,600,200) #number of elements

for j in range(1,A+1):
    a2=[]
    a3=[]
    t1=-5
     
    for N in q:
        
        def Tim(k):
            H=100
            rho=2000000
            a=1
            c=25
            b=10*(math.exp((k*H**2)/(2*rho))-1)
            d=b**2-4*a*c
            R= (-b+math.sqrt(d))/(2*a)
            return R
    
        
        def Time(k):
            H=100
            rho=2000000
            a=1
            c=25
            b2=(((Tim(N)+t1)**2)/(4*t1*Tim(N)))
            b1=(((Tim(N)+t1)**2)/(4*t1*Tim(N)))**(1/N)
            b=20*b1*b2-10
            d=b**2-4*a*c
            R= (-b+math.sqrt(d))/(2*a)
            return R
        
        T1=Tim(N)
        T=Time(N)
        x2=(t1-T)/2
        x21=x2=(t1-T1)/2
        x1=-x2
        x11=-x21
        L=[]
        L21=[]
        L3=[]
        U=[]
        count=0
        count1=0
        count2=0
        while count<N:
            R1 = np.random.uniform(0,1)
            R2 = np.random.uniform(0,1)
            lx=R1*(x2-x1)+x1
            lt=(T*t1)/(R2*(t1-T)+T)
            lx1=R1*(x21-x11)+x11
            lt1=(T1*t1)/(R2*(t1-T1)+T1)
            L2=[]
            if (np.square((lt)-(t1))>np.square(lx)and np.square((lt)-(T))>np.square(lx)):
                count+=1
                tuple=[lx,lt]
                L.append(tuple)
                if (np.square((lt1)-(t1))>np.square(lx1) and np.square((lt1)-(T1))>np.square(lx1)) and (np.square((lt)-(t1))>np.square(lx)and np.square((lt)-(T))>np.square(lx)):
                    count1+=1
                else:    
                    count2+=1
                    tuple=[lx,lt]
                    L2.append(tuple)
            L21.extend(L2)
        a3.append(L21)
    a5.append(a3)


n=[]
for i in range(len(a5)):
    n.extend(a5[i][0])
nr=random.choice(n)
print(nr)
# Out:
# 1
# [1.4362585550896148, -3.5616521276898836]

# %%
#For 500 points, Calculate S and S prime and later check if they follow constant slope (501/500).

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import math
import random

A=int(input()) #Number of time this code can be interated
a4=[]
a41=[]
q=range(500,600,200) #number of elements

for j in range(1,A+1):
    a2=[]
    a3=[]
    t1=-5
    ##Two Dimension
        
        
    for N in q:
        
            
        def Tim(k):
            H=100
            rho=2000000
            a=1
            c=25
            b=10*(math.exp((k*H**2)/(2*rho))-1)
            d=b**2-4*a*c
            R= (-b+math.sqrt(d))/(2*a)
            return R
    

        T=Tim(N)
        x2=(t1-T)/2
        x1=-x2
        L=[]
        L0=[]
        count=0
        count1=0
        
        while count<N:
            R1 = np.random.uniform(0,1)
            R2 = np.random.uniform(0,1)
            R3= np.random.uniform(0,1)
            R4=np.random.uniform(0,1)
            lx=R1*(x2-x1)+x1
            lt=(T*t1)/(R2*(t1-T)+T)
            lx1=R1*(x2-x1)+x1
            lt1=(T*t1)/(R2*(t1-T)+T)
            if (np.square((lt)-(t1))>np.square(lx)and np.square((lt)-(T))>np.square(lx)):
                count+=1
                tuple=[lx,lt]
                L.append(tuple)
            if (np.square((lt1)-(t1))>np.square(lx1)and np.square((lt1)-(T))>np.square(lx1)):
                count1+=1
                tuple=[lx1,lt1]
                L0.append(tuple)
            
        x=[0,T]
        y=[0,t1]
        
        
        L.append(x)
        L.append(y)
        
        
        L0.append(x)
        L0.append(y)
        #Add above random point to the list L0 
        L0.append(nr)
        
        #Sort L and Lo according to increasing time
        
        def takeSecond(elem):
            return elem[1]    
        L.sort(key=takeSecond) 
        
        def takeSecond(elem):
            return elem[1]    
        L0.sort(key=takeSecond) 
        
        a9=[]
        
        #R is the old relation matrix with elements 500
        R=[]
        for j in range(len(L)):
            R.append([])
            for i in range(len(L)):
                if (np.square(L[i][1]-L[j][1])>= np.square(L[i][0]-L[j][0]) and L[i][1]> L[j][1]):
                    R[j].append(1) 
                else:
                    R[j].append(0)
        I=np.identity(len(R))
        R1=np.dot(I,R)
        R2=np.dot(R,R)
        R3=np.dot(R,R2)
        c3=R3[0][len(R2)-1]
        Act=36*((4*c3/(N*(N-1))-1)) #Old Action (S)
        
        #Y4 is the new relation matrix with elements 501
        Y4=[]
        for j in range(len(L0)):
            Y4.append([])
            for i in range(len(L0)):
                if (np.square(L0[i][1]-L0[j][1])>= np.square(L0[i][0]-L0[j][0]) and L0[i][1]> L0[j][1]):
                    Y4[j].append(1) 
                else:
                    Y4[j].append(0)
        I=np.identity(len(Y4))
        Y5=np.dot(I,Y4)
        Y6=np.dot(Y4,Y4)
        Y7=np.dot(Y4,Y6)
        c7=Y7[0][len(Y6)-1]
        Act1=36*((4*c7/(N*(N-1))-1)) #New Action (S')
        
        plt.figure(j)
        plt.scatter(Act,Act1, color='cyan') 
        plt.xlabel('S')
        plt.ylabel('S\u2032')
        plt.grid(True, linestyle='--')
        plt.legend(["N=500 points "], ncol = 2 , loc = "upper left") 

        
plt.xlim(0,5)
plt.plot([0,1.002,2.004,3.006,4.008,5.010], color="red")
plt.savefig('2D.pdf')
plt.legend(["S\u2032=(501)/500 S "], ncol = 2 )
# Out:
# 100
# <img src="data:image/png;base64,..." width="640">
