# %%
#Two Dimensional Sprinkling in Minkowski Spacetime for 1000 points

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import math

q=range(1000,1200,250) #number of elements

for j in range(1,A+1):
    a2=[]
    t1=-1
    t2=0
     
    for N in q:
        x2=(t2-t1)/2
        x1=-x2
        L=[]
        count=0
        #Obatin points that lie inside the Alexendrov interval(Diamond shape) for each number of points(N) 
        while count<N:
            R1 = np.random.uniform(0,1)
            R2 = np.random.uniform(0,1)
            lx=R2*(x2-x1)+x1
            lt= R1*(t2-t1)+t1
            if (np.square((lt)-(t1))>np.square(lx) and np.square((lt)-(t2))>np.square(lx)):
                count+=1
                tuple=[lx,lt]
                L.append(tuple)
        
        x=[0,0]
        k=[-0.5,-0.5]
        m=[0.5,-0.5]
        y=[0,-1]
        lx,lt = map(list,zip(*L))
        
        #Scatter the points 
        plt.figure(j)
        plt.scatter(lx,lt, color='cyan')                
        plt.scatter(0,0, color='cyan')
        plt.scatter(0,-1, color='cyan')
        plt.scatter(-0.5,-0.5, color='cyan')
        plt.scatter(0.5,-0.5, color='cyan')
        plt.savefig('3D.pdf')
        
        #Plot the equations
        x_values = [k[0], x[0]]
        y_values = [k[1], x[1]]  
        x1_values = [m[0], y[0]]
        y1_values = [m[1], y[1]]
        plt.plot(x_values, y_values,'bo', linestyle="--")
        plt.plot(x1_values, y1_values,'bo', linestyle="--")
        
        x2_values = [x[0], m[0]]
        y2_values = [x[1], m[1]]  
        x3_values = [k[0], y[0]]
        y3_values = [k[1], y[1]]
        plt.plot(x2_values, y2_values,'bo', linestyle="--")
        plt.plot(x3_values, y3_values,'bo', linestyle="--")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Two Dimensional Sprinkling in De Sitter spacetime keeping constant density of 2000000

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import math


q=range(1000,1200,220) #Range of number of elements

for j in range(1,A+1):
    a2=[]
    t1=-5
     
    for N in q:
        
    #Time(k) solves the time required to maintain the uniform density of rho=2000000 as we increase more points 
        def Time(k):
            H=100
            rho=2000000
            a=1
            c=25
            b=10*(math.exp((k*H**2)/(2*rho))-1)
            d=b**2-4*a*c
            R= (-b+math.sqrt(d))/(2*a)
            return R
        
        T=Time(N)
        x2=(t1-T)/2
        x1=-x2
        L=[]
        count=0
        
        #Obatin points that lie inside the Alexendrov interval(Diamond shape) for each number of points(N)
        while count<N:
            R1 = np.random.uniform(0,1)
            R2 = np.random.uniform(0,1)
            lx=R1*(x2-x1)+x1
            lt=(T*t1)/(R2*(t1-T)+T)
            if (np.square((lt)-(t1))>np.square(lx)and np.square((lt)-(T))>np.square(lx)):
                count+=1
                tuple=[lx,lt]
                L.append(tuple)
        
        x=[0,T]
        k=[x2,(t1+T)/2]
        m=[x1,(t1+T)/2]
        y=[0,t1]
        lx,lt = map(list,zip(*L))
        
        #Scatter points
        plt.figure(j)
        plt.scatter(lx,lt, color='cyan')                
        plt.scatter(0,T, color='cyan')
        plt.scatter(0,t1, color='cyan')
        plt.scatter(x2,(t1+T)/2, color='cyan')
        plt.scatter(x1,(t1+T)/2, color='cyan')
        plt.savefig('3D.pdf')
        
        #Plot equations
        x_values = [k[0], x[0]]
        y_values = [k[1], x[1]]  
        x1_values = [m[0], y[0]]
        y1_values = [m[1], y[1]]
        plt.plot(x_values, y_values,'bo', linestyle="--")
        plt.plot(x1_values, y1_values,'bo', linestyle="--")
        
        x2_values = [x[0], m[0]]
        y2_values = [x[1], m[1]]  
        x3_values = [k[0], y[0]]
        y3_values = [k[1], y[1]]
        plt.plot(x2_values, y2_values,'bo', linestyle="--")
        plt.plot(x3_values, y3_values,'bo', linestyle="--")
# Out:
# <img src="data:image/png;base64,..." width="640">
